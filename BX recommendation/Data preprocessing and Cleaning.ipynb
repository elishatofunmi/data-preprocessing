# %%
import numpy as np
import pandas as pd
import sklearn as sk
import warnings
warnings.filterwarnings('ignore')

# %%
read_ratings = pd.read_csv(u'BX-Book-Ratings.csv', error_bad_lines = False, encoding='ISO-8859-1')
read_books = pd.read_csv(u'BX-Books.csv', error_bad_lines = False, encoding='ISO-8859-1')
read_users = pd.read_csv(u'BX-Users.csv', error_bad_lines = False, encoding='ISO-8859-1')
# Out:
# b'Skipping line 438648: expected 1 fields, saw 3\n'
# b'Skipping line 543301: expected 1 fields, saw 2\nSkipping line 723139: expected 1 fields, saw 2\nSkipping line 738100: expected 1 fields, saw 2\nSkipping line 908732: expected 1 fields, saw 2\n'
# ...

# %%
read_ratings.head()
# Out:
#   User-ID;"ISBN";"Book-Rating"
# 0      276725;"034545104X";"0"
# 1      276726;"0155061224";"5"
# 2      276727;"0446520802";"0"
# 3      276729;"052165615X";"3"
# 4      276729;"0521795028";"6"

# %%
read_ratings.shape
# Out:
# (1149775, 1)

# %%
def segregate(data):
    key = data.keys()[0].split(';')
    dict_key = {key[0]:[], key[1]:[], key[2]:[]}
    for i in data[data.keys()[0]]:
        new_split = i.split(';')
        dict_key[key[0]].append(new_split[0])
        dict_key[key[1]].append(new_split[1])
        dict_key[key[2]].append(new_split[2])
    frame = pd.DataFrame(dict_key)
    return frame

frame_ratings = segregate(read_ratings)

# %%
frame_ratings.head()
# Out:
#   User-ID        "ISBN" "Book-Rating"
# 0  276725  "034545104X"           "0"
# 1  276726  "0155061224"           "5"
# 2  276727  "0446520802"           "0"
# 3  276729  "052165615X"           "3"
# 4  276729  "0521795028"           "6"

# %%
frame_books = segregate(read_books)
frame_books.head()
# Out:
#          ISBN                                       "Book-Title"  \
# 0  0195153448                              "Classical Mythology"
# 1  0002005018                                     "Clara Callan"
# 2  0060973129                             "Decision in Normandy"
# 3  0374157065  "Flu: The Story of the Great Influenza Pandemi...
# 4  0393045218                           "The Mummies of Urumchi"
#
#             "Book-Author"
# 0    "Mark P. O. Morford"
# 1  "Richard Bruce Wright"
# 2          "Carlo D'Este"
# 3      "Gina Bari Kolata"
# 4       "E. J. W. Barber"

# %%
read_users.head()
# Out:
#                                 User-ID;"Location";"Age"
# 1;"nyc          new york                       usa";NULL
# 2;"stockton     california                     usa";"18"
# 3;"moscow       yukon territory             russia";NULL
# 4;"porto        v.n.gaia                  portugal";"17"
# 5;"farnborough  hants               united kingdom";NULL

# %%
count = 0
for k in read_users[read_users.keys()[0]]:
    if count < 5:
        new_split = k.split(';')
        print(len(new_split))
        count += 1
    else:
        count += 1
        break
# Out:
# 2
# 2
# 2
# 2
# 2

# %%
new_dict = {'Location':[], 'Age':[]}
for k in read_users[read_users.keys()[0]]:
    new_split = k.split(';')
    new_dict['Location'].append(new_split[0])
    new_dict['Age'].append(new_split[1])
    
frame_users = pd.DataFrame(new_dict)
frame_users.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-07088b35f070> in <module>()
#       1 new_dict = {'Location':[], 'Age':[]}
#       2 for k in read_users[read_users.keys()[0]]:
# ----> 3     new_split = k.split(';')
#       4     new_dict['Location'].append(new_split[0])
#       5     new_dict['Age'].append(new_split[1])
#
# AttributeError: 'float' object has no attribute 'split'

# %%
count = 0
for k in read_users:
    if count == 5:
        break
    else:
        print(k)
# Out:
# User-ID;"Location";"Age"

# %%
frame_users = segregate(read_users)
frame_users.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-d38d49184237> in <module>()
# ----> 1 frame_users = segregate(read_users)
#       2 frame_users.head()
#
# <ipython-input-12-1ffe0df64fbd> in segregate(data)
#       8         dict_key[key[0]].append(new_split[0])
#       9         dict_key[key[1]].append(new_split[1])
# ---> 10         dict_key[key[2]].append(new_split[2])
#      11     frame = pd.DataFrame(dict_key)
#      12     return frame
#
# IndexError: list index out of range

# %%
read_books.head()

# %%
read_users.head()
