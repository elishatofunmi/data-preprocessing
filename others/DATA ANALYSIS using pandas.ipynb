# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
plt.plot([1,2,3,5,3,1,2,3,4,2,3,2,5,6,6,7])
plt.show()

# %% [markdown]
# The basic plot in matplotib contains the following elements:
# x and y axes: These are both horizontal and vertical axes
# x and y tickers: These are little tickers denoting the segments of axes. There can be major or minor tickers.
# x and y tick labels: These represent values on particular axis.
# plotting area: This is where the actual plots are drawn.

# %%
plt.plot([1,2,3,4,2,4,1,3,2,3], [3,4,5,2,4,2,3,2,6,7])
plt.show()

# %%
# some simple data
x = [1,2,3,4]
y = [5,4,3,2]
# create new figure
figure()


# divide subplots into 2 * 3 grid
## and select #1

fig.subplot(231)
plt.plot(x,y)

# select #2
subplot(232)
plt.bar(x,y)

# horizontal bar-charts
subplot(233)
plt.barh(x,y)

# create stacked bar charts
subplot(234)
plt.bar(x,y)

# we need more data for stacked bar charts
y1 = [7,8,5,3]
plt.bar(x,y1, bottom = y, color = 'r')

# box plot
subplot(235)
plt.boxplot(x)

# scatter plot
subplot(236)
plt.scatter(x,y)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-49fdbd113c5c> in <module>()
#       3 y = [5,4,3,2]
#       4 # create new figure
# ----> 5 figure()
#       6
#       7
#
# NameError: name 'figure' is not defined
