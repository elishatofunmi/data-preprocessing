# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
file = pd.read_csv(r'C:\bootcamp\Data Science Bootcamp Data_2.0.csv')

# %%
file.head()
# Out:
#            Quest No    Age       Gender      Employment Category  \
# 0  ABJ/2015/002/196  31-35  No Response     Civil/Public Servant
# 1  ABJ/2015/002/196  31-35  No Response     Civil/Public Servant
# 2  KAN/2015/001/228  31-35  No Response            Self Employed
# 3  KAN/2015/001/228  31-35  No Response            Self Employed
# 4   KAN/2015/04/061  21-30         Male  Private Sector Employee
#
#            Education              Income Location    Bank  No of Years   \
# 0            OND/HND  N50,000 - N100,000    Abuja  Bank A          12.0
# 1            OND/HND  N50,000 - N100,000    Abuja  Bank M           6.0
# 2  Bachelor's Decree       Below N50,000     Kano  Bank J           2.0
# 3  Bachelor's Decree       Below N50,000     Kano  Bank B           NaN
# 4  Bachelor's Decree       Below N50,000     Kano  Bank C           5.0
#
#   Most frequently used Bank      ...      Payint Paycab Mig1 Mig2 Mig3  \
# ...

# %%
print (file.keys())
print (len(file.keys()))
# Out:
# Index(['Quest No', 'Age', 'Gender', 'Employment Category', 'Education',
#        'Income', 'Location', 'Bank', 'No of Years ',
#        'Most frequently used Bank',
#        ...
#        'Payint', 'Paycab', 'Mig1', 'Mig2', 'Mig3', 'Rec', 'Changeplan',
#        'FromBank', 'ToBank', 'ChangeReasons'],
#       dtype='object', length=152)
# 152

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42653 entries, 0 to 42652
# Columns: 152 entries, Quest No to ChangeReasons
# dtypes: float64(89), object(63)
# memory usage: 49.5+ MB

# %%
file.describe()
# Out:
#        No of Years        impcc1a          cc1a       impcc1b          cc1b  \
# count  41386.000000  38400.000000  38400.000000  39587.000000  39587.000000
# mean       6.113227      7.542396      4.945365      7.978478      5.112385
# std        4.801078      2.524790      1.287591      2.170216      1.230897
# min        0.000000      1.000000      1.000000      1.000000      1.000000
# 25%        3.000000      6.000000      4.000000      7.000000      5.000000
# 50%        5.000000      8.000000      5.000000      8.000000      5.000000
# 75%        8.000000     10.000000      6.000000     10.000000      6.000000
# max       55.000000     10.000000      7.000000     10.000000      7.000000
#
#              impcc2           cc2        impcc3           cc3        impcc4  \
# count  40265.000000  40265.000000  40244.000000  40244.000000  39460.000000
# mean       8.046045      5.218875      8.148022      5.171678      8.298302
# ...

# %%
#reading in the excel file
file_excel = pd.read_excel(r'C:\bootcamp\Data Science Bootcamp Data_2.0.xlsx')

# %%
create = {}
for i, j in zip(file.keys(), file_excel['Description']):
    print (i,    j)
    
#print (create)
# Out:
# Quest No Questionnaire number
# Age Age
# Gender Gender
# Employment Category Employment category
# Education Education
# Income Income
# Location Location
# Bank Banks you use
# No of Years  Number of years of banking relationship
# Most frequently used Bank Most Frequently Used Bank
# RatQOS nan
# RatFS Quality of service experience
# RatIR Financial stability
# RatERSA Image and reputation
# RatPOBR Employer requirements (Salary account)
# RatRFF Proximity of branches
# FreqBra Recommendations from family and friends
# FreqATM nan
# FreqPOS Branch
# FreqInt ATM
# FreqMob POS
# FreqUSSD Internet banking
# FreqTel Mobile (App)
# MostfreqATM USSD Banking
# ATMproximity Call Centre
# ATMqon nan
# ATMsecurity Most Frequently used Bank's ATM
# ATMros nan
# Device1 Proximity
# Device2 Quality of notes
# Device3 Secure environment
# Device4 Reliability of service
# Cshwit nan
# Cshdep Desktop
# Fndtrf Laptop
# Balenq Tablet
# Mkgcmp Smart phones
# Mkgpay nan
# Gtloan Cash Withdrawal
# ...

# %%
x = []
for i in file['Income']:
    if i not in x:
        x.append(i)
    else:
        pass
print (x)
# Out:
# ['N50,000 - N100,000', 'Below N50,000', 'No Response', 'N101,000 - N250,000', 'N251,000 - N500,000', 'N501,000 - N1 Million', 'Greater than N1 million', nan]

# %%
# count the number of those in each segement and show their percentage
#str_var = 'N50,000 - N100,000'
##count = 0
#for k in file['Income']:
#    if str_var == k:
#count += 1
      
#print ('percentage of ' , str_var , 'in is: ', count/len(file['Income']))



CreateDic_keys =[]
CreateDic_values = []
for i in file['Income']:
    
    if i not in CreateDic_keys:
        CreateDic_keys.append(i)

print (CreateDic_keys)

for j in CreateDic_keys: 
    count = 0
    for k in file['Income']:
        if j== k:
            count += 1
    CreateDic_values.append(count)
print (CreateDic_values)
#zipped_value = zip(CreateDic_keys, CreateDic_values)
#print (zipped_value)
# Out:
# ['N50,000 - N100,000', 'Below N50,000', 'No Response', 'N101,000 - N250,000', 'N251,000 - N500,000', 'N501,000 - N1 Million', 'Greater than N1 million', nan]
# [13415, 19042, 1352, 5995, 1881, 697, 270, 0]

# %%
plt.pie(CreateDic_values, labels = CreateDic_keys, radius = 2)
plt.show()

# %%
file['Income'].value_counts()
# Out:
# Below N50,000              19042
# N50,000 - N100,000         13415
# N101,000 - N250,000         5995
# N251,000 - N500,000         1881
# No Response                 1352
# N501,000 - N1 Million        697
# Greater than N1 million      270
# Name: Income, dtype: int64

# %%
#plt.Circle(file['Income'])
#plt.show()
#print (x)
test_file = file.copy()
test_file['Income'][test_file['Income']=='N50,000 - N100,000'] = 1
test_file['Income'][test_file['Income']=='Below N50,000'] = 2
test_file['Income'][test_file['Income']=='No Response'] = 3
test_file['Income'][test_file['Income']=='N101,000 - N250,000'] = 4
test_file['Income'][test_file['Income']=='N251,000 -N500,000'] = 5
test_file['Income'][test_file['Income']=='N501,000 - N1 Million'] = 6
test_file['Income'][test_file['Income']=='Greater than N1 million'] = 7
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# ...

# %%
# employment category
dic_emp_cat = {}
dic_emp_cat = dict(test_file['Employment Category'].value_counts())
print (dic_emp_cat.values())
# Out:
# dict_values([11537, 9779, 9337, 7597, 1500, 1303, 1233, 366])

# %%
file.head()
# Out:
#            Quest No    Age       Gender      Employment Category  \
# 0  ABJ/2015/002/196  31-35  No Response     Civil/Public Servant
# 1  ABJ/2015/002/196  31-35  No Response     Civil/Public Servant
# 2  KAN/2015/001/228  31-35  No Response            Self Employed
# 3  KAN/2015/001/228  31-35  No Response            Self Employed
# 4   KAN/2015/04/061  21-30         Male  Private Sector Employee
#
#            Education              Income Location    Bank  No of Years   \
# 0            OND/HND  N50,000 - N100,000    Abuja  Bank A          12.0
# 1            OND/HND  N50,000 - N100,000    Abuja  Bank M           6.0
# 2  Bachelor's Decree       Below N50,000     Kano  Bank J           2.0
# 3  Bachelor's Decree       Below N50,000     Kano  Bank B           NaN
# 4  Bachelor's Decree       Below N50,000     Kano  Bank C           5.0
#
#   Most frequently used Bank      ...      Payint Paycab Mig1 Mig2 Mig3  \
# ...

# %%
# age, income, gender, employment category, education.test_file['Income']
# apply clustering using KMeans 
from sklearn.cluster import KMeans

# %%
processing_file = file[['Age', 'Gender', 'Employment Category', 'Education', 'Income', 'Location','Bank', 'No of Years ', 'Most frequently used Bank' ]]

# %%
processing_file.head()
# Out:
#      Age       Gender      Employment Category          Education  \
# 0  31-35  No Response     Civil/Public Servant            OND/HND
# 1  31-35  No Response     Civil/Public Servant            OND/HND
# 2  31-35  No Response            Self Employed  Bachelor's Decree
# 3  31-35  No Response            Self Employed  Bachelor's Decree
# 4  21-30         Male  Private Sector Employee  Bachelor's Decree
#
#                Income Location    Bank  No of Years  Most frequently used Bank
# 0  N50,000 - N100,000    Abuja  Bank A          12.0                    Bank A
# 1  N50,000 - N100,000    Abuja  Bank M           6.0                    Bank A
# 2       Below N50,000     Kano  Bank J           2.0                    Bank B
# 3       Below N50,000     Kano  Bank B           NaN                    Bank B
# 4       Below N50,000     Kano  Bank C           5.0                    Bank C

# %%
# processing the banks in Bank

created_bank_dict = dict(processing_file['Bank'].value_counts())
print (created_bank_dict)
Values = created_bank_dict.values()
keys = created_bank_dict.keys()
file_copy_pros = processing_file.copy()

file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank A'] = 1
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank B'] = 2
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank C'] = 3
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank D'] = 4
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank E'] = 5
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank F'] = 6
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank G'] = 7
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank H'] = 8
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank I'] = 9
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank J'] = 10
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank K'] = 11
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank L'] = 12
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank M'] = 13
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank N'] = 14
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank O'] = 15
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank P'] = 16
file_copy_pros['Bank'][file_copy_pros['Bank'] == 'Bank Q'] = 17

#file_copy_pros['Bank']
# Out:
# {'Bank C': 6754, 'Bank B': 6063, 'Bank A': 4360, 'Bank D': 4203, 'Bank H': 3959, 'Bank L': 2634, 'Bank N': 2522, 'Bank G': 1995, 'Bank F': 1921, 'Bank J': 1837, 'Bank I': 1158, 'Bank K': 1060, 'Bank E': 1011, 'Bank O': 944, 'Bank Q': 815, 'Bank P': 590, 'Bank M': 562}
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# ...

# %%
created_Gender_dict = dict(file_copy_pros['Gender'].value_counts())
print (created_Gender_dict)
file_copy_pros['Gender'][file_copy_pros['Gender']== 'Male'] = 1
file_copy_pros['Gender'][file_copy_pros['Gender']== 'Female'] = 2
file_copy_pros['Gender'][file_copy_pros['Gender']== 'No Response'] = 3
file_copy_pros.head()
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# {'Male': 21755, 'Female': 18808, 'No Response': 2089}
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
created_location_dict = dict(file_copy_pros['Location'].value_counts())
print (created_location_dict)
count = 1
for a in created_location_dict.keys():
    file_copy_pros['Location'][file_copy_pros['Location'] == a] = count
    count += 1
    
file_copy_pros.head()
# Out:
# {'Lagos': 13618, 'Abuja': 3521, 'Port Harcourt': 2487, 'Ibadan': 2139, 'Onitsha': 1795, 'Benin': 1643, 'Kaduna': 1540, 'Abeokuta': 1528, 'Asaba': 1481, 'Kano': 1347, 'Enugu': 1218, 'Aba': 1197, 'Jos': 952, 'Lokoja': 864, 'Ilorin': 759, 'Owerri': 755, 'Akure': 691, 'Calabar': 688, 'Nnewi': 659, 'Minna': 650, 'Osogbo': 574, 'Ado-Ekiti': 526, 'Makurdi': 526, 'Uyo': 503, 'Sokoto': 384, 'Katsina': 304, 'Yola': 298, 'Nasarrawa': 3, 'Bauchi': 2}
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Age Gender      Employment Category          Education  \
# 0  31-35      3     Civil/Public Servant            OND/HND
# 1  31-35      3     Civil/Public Servant            OND/HND
# 2  31-35      3            Self Employed  Bachelor's Decree
# ...

# %%
created_income_dict = dict(file_copy_pros['Income'].value_counts())
#print (created_income_dict)
count = 1
for a in created_income_dict.keys():
    file_copy_pros['Income'][file_copy_pros['Income'] == a] = count
    count += 1
    
file_copy_pros.head()
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Age Gender      Employment Category          Education Income Location  \
# 0  31-35      3     Civil/Public Servant            OND/HND      2        2
# 1  31-35      3     Civil/Public Servant            OND/HND      2        2
# 2  31-35      3            Self Employed  Bachelor's Decree      1       10
# 3  31-35      3            Self Employed  Bachelor's Decree      1       10
# 4  21-30      1  Private Sector Employee  Bachelor's Decree      1       10
#
#   Bank  No of Years  Most frequently used Bank
# 0    1          12.0                    Bank A
# 1   13           6.0                    Bank A
# 2   10           2.0                    Bank B
# ...

# %%
created_Employ_dict = dict(file_copy_pros['Employment Category'].value_counts())
count = 1
for a in created_Employ_dict.keys():
    file_copy_pros['Employment Category'][file_copy_pros['Employment Category'] == a] = count
    count += 1
    
file_copy_pros.head()
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#      Age Gender Employment Category          Education Income Location Bank  \
# 0  31-35      3                   4            OND/HND      2        2    1
# 1  31-35      3                   4            OND/HND      2        2   13
# 2  31-35      3                   3  Bachelor's Decree      1       10   10
# 3  31-35      3                   3  Bachelor's Decree      1       10    2
# 4  21-30      1                   2  Bachelor's Decree      1       10    3
#
#    No of Years  Most frequently used Bank
# 0          12.0                    Bank A
# 1           6.0                    Bank A
# 2           2.0                    Bank B
# ...

# %%
created_Education_dict = dict(file_copy_pros['Education'].value_counts())
count = 1
for a in created_Education_dict.keys():
    file_copy_pros['Education'][file_copy_pros['Education'] == a] = count
    count += 1
    
file_copy_pros.head()
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#      Age Gender Employment Category Education Income Location Bank  \
# 0  31-35      3                   4         2      2        2    1
# 1  31-35      3                   4         2      2        2   13
# 2  31-35      3                   3         1      1       10   10
# 3  31-35      3                   3         1      1       10    2
# 4  21-30      1                   2         1      1       10    3
#
#    No of Years  Most frequently used Bank
# 0          12.0                    Bank A
# 1           6.0                    Bank A
# 2           2.0                    Bank B
# 3           NaN                    Bank B
# ...

# %%
created_freq_dict = dict(file_copy_pros['Most frequently used Bank'].value_counts())
count = 1
for a in created_freq_dict.keys():
    file_copy_pros['Most frequently used Bank'][file_copy_pros['Most frequently used Bank'] == a] = count
    count += 1
    
file_copy_pros.head()
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#      Age Gender Employment Category Education Income Location Bank  \
# 0  31-35      3                   4         2      2        2    1
# 1  31-35      3                   4         2      2        2   13
# 2  31-35      3                   3         1      1       10   10
# 3  31-35      3                   3         1      1       10    2
# 4  21-30      1                   2         1      1       10    3
#
#    No of Years  Most frequently used Bank
# 0          12.0                         3
# 1           6.0                         3
# 2           2.0                         2
# 3           NaN                         2
# ...

# %%
final_test = file_copy_pros.copy()

created_age_dict = dict(final_test['Age'].value_counts())

count = 1
for a in created_age_dict.keys():
    final_test['Age'][final_test['Age'] == a] = count
    count += 1
    
final_test.head()
# Out:
# C:\Users\ACER\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#   Age Gender Employment Category Education Income Location Bank  No of Years   \
# 0   2      3                   4         2      2        2    1          12.0
# 1   2      3                   4         2      2        2   13           6.0
# 2   2      3                   3         1      1       10   10           2.0
# 3   2      3                   3         1      1       10    2           NaN
# 4   1      1                   2         1      1       10    3           5.0
#
#   Most frequently used Bank
# 0                         3
# 1                         3
# 2                         2
# 3                         2
# 4                         1

# %%
# imputing the NaN values in no of years with 0
final_test['No of Years '].fillna(final_test['No of Years '].mean())
   # else:
    #    pass
    #count += 1
    
final_test.head()
# Out:
#   Age Gender Employment Category Education Income Location Bank  No of Years   \
# 0   2      3                   4         2      2        2    1          12.0
# 1   2      3                   4         2      2        2   13           6.0
# 2   2      3                   3         1      1       10   10           2.0
# 3   2      3                   3         1      1       10    2           NaN
# 4   1      1                   2         1      1       10    3           5.0
#
#   Most frequently used Bank
# 0                         3
# 1                         3
# 2                         2
# 3                         2
# 4                         1

# %%
experiment = final_test[['Age', 'Gender', 'Employment Category', 'Education', 'Income','Location','Bank','Most frequently used Bank']]
print (experiment.head())
# Out:
#   Age Gender Employment Category Education Income Location Bank  \
# 0   2      3                   4         2      2        2    1
# 1   2      3                   4         2      2        2   13
# 2   2      3                   3         1      1       10   10
# 3   2      3                   3         1      1       10    2
# 4   1      1                   2         1      1       10    3
#
#   Most frequently used Bank
# 0                         3
# 1                         3
# 2                         2
# 3                         2
# 4                         1

# %%
experiment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42653 entries, 0 to 42652
# Data columns (total 8 columns):
# Age                          42652 non-null object
# Gender                       42652 non-null object
# Employment Category          42652 non-null object
# Education                    42652 non-null object
# Income                       42652 non-null object
# Location                     42652 non-null object
# Bank                         42388 non-null object
# Most frequently used Bank    38975 non-null object
# dtypes: object(8)
# memory usage: 2.6+ MB

# %%
experiment.describe()
# Out:
#           Age  Gender  Employment Category  Education  Income  Location  \
# count   42652   42652                42652      42652   42652     42652
# unique      7       3                    8          9       7        29
# top         1       1                    1          1       1         1
# freq    16503   21755                11537      17163   19042     13618
#
#          Bank  Most frequently used Bank
# count   42388                      38975
# unique     17                         17
# top         3                          1
# freq     6754                       7699

# %%
count = 0
for A in experiment.keys():
    if k in experiment[A] < 1:
        solution = np.floor(k)
        experiment[A][count].replace(k, solution)
    count += 1

experiment.head()
# Out:
#   Age Gender Employment Category Education Income Location Bank  \
# 0   2      3                   4         2      2        2    1
# 1   2      3                   4         2      2        2   13
# 2   2      3                   3         1      1       10   10
# 3   2      3                   3         1      1       10    2
# 4   1      1                   2         1      1       10    3
#
#   Most frequently used Bank
# 0                         3
# 1                         3
# 2                         2
# 3                         2
# 4                         1

# %%
sns.set_style('whitegrid')
sns.boxplot(experiment['Age'])
plt.show()

# %%
# plotting box plot of datasets
# to figure out extreme values or outliers
box_plot_of_experiment = experiment
for i in box_plot_of_experiment:
    sns.set_style('whitegrid')
    sns.boxplot(box_plot_of_experiment[i])
    plt.show()

# %%
# takiing out exreme values
review_education = experiment[experiment['Education'] <6]
review_income = experiment[experiment['Income'] < 3]
review_Location = experiment[experiment['Location'] <26]
review_bank_used = experiment[experiment['Most frequently used Bank']< 14]
review_age = experiment['Age']
review_gender = experiment['Gender']
review_employment_category = experiment['Employment Category']
review_education = experiment['Education']
review_bank_type = experiment['Bank']

# converting to dictionary
review_dict = {}
review_dict['Age'] = review_age
review_dict['Gender'] = review_gender
review_dict['Employment Category'] = review_employment_category
review_dict['Education']= review_education 
review_dict['Income'] = review_income
review_dict['Location'] = review_Location
review_dict['Bank'] = review_bank_type
review_dict['Most frequently used bank'] = review_bank_used

# %%
# to series
series_form = pd.Series(review_dict.values(), index = review_dict.keys())

# %%
# Convert review_dict to a dataframe


#Dataframe_answer = pd.DataFrame(series_form)
#print (Dataframe_answer)
help (np.random.normal)
# Out:
# Help on built-in function normal:
#
# normal(...) method of mtrand.RandomState instance
#     normal(loc=0.0, scale=1.0, size=None)
#
#     Draw random samples from a normal (Gaussian) distribution.
#
#     The probability density function of the normal distribution, first
#     derived by De Moivre and 200 years later by both Gauss and Laplace
#     independently [2]_, is often called the bell curve because of
#     its characteristic shape (see the example below).
#
#     The normal distributions occurs often in nature.  For example, it
#     describes the commonly occurring distribution of samples influenced
#     by a large number of tiny, random disturbances, each with its own
#     unique distribution [2]_.
#
#     Parameters
#     ----------
#     loc : float or array_like of floats
#         Mean ("centre") of the distribution.
#     scale : float or array_like of floats
#         Standard deviation (spread or "width") of the distribution.
# ...

# %%
# building the clustering model
kmeans = KMeans(n_clusters = 6, random_state = 20)
kmeans.fit(experiment)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-c6f9abc710bb> in <module>()
#       1 # building the clustering model
#       2 kmeans = KMeans(n_clusters = 6, random_state = 20)
# ----> 3 kmeans.fit(experiment)
#
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y)
#     878         """
#     879         random_state = check_random_state(self.random_state)
# --> 880         X = self._check_fit_data(X)
#     881
#     882         self.cluster_centers_, self.labels_, self.inertia_, self.n_iter_ = \
#
# C:\Users\ACER\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in _check_fit_data(self, X)
#     852     def _check_fit_data(self, X):
#     853         """Verify that the number of samples given is larger than k"""
# --> 854         X = check_array(X, accept_sparse='csr', dtype=[np.float64, np.float32])
# ...

# %%
float_file = experiment.copy()
for i in float_file.keys():
    for j in float_file[i]:
        float_file[i].replace(j, np.float(j))

# %%
from sklearn.datasets import make_blobs

# %%
from sklearn.cluster import KMeans

# %%
X, y = make_blobs(random_state = 1)

# %%
print (X,y)
